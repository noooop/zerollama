# %% [markdown]
# # 2. multi-agent-competitive 对抗型 - 两个大模型相互对话

# %% [markdown]
# 首先将zerollama目录加入python path

# %%
import os
import sys
from pathlib import Path
pwd = Path(os.getcwd())
sys.path.append(str(pwd.parent.parent.parent))
os.chdir(str(pwd.parent.parent.parent))

# %% [markdown]
# 导入RolePlayingAgent、Session 后续会介绍

# %%
from zerollama.agents import RolePlayingAgent
from zerollama.agents import Session

# %% [markdown]
# 设定 llm 参数

# %%
llm_config = {"model": "Qwen/Qwen2-7B-Instruct-GPTQ-Int4", "type": "openai", "base_url": 'http://localhost:8080/v1/'}

# %% [markdown]
# 加入第一个llm驱动的角色：主持人，一位辩论赛主持人。

# %%
host = RolePlayingAgent(
    name="主持人",
    system_message=
    "你的名字是主持人，你是一位辩论赛主持人。"
    "最先发言，然后依次让正反方轮流发言"
    "只负责流程，不输出观点，不总结观点。"
    "只负责流程，不输出观点，不总结观点。"
    "只负责流程，不输出观点，不总结观点。",
    llm_config=llm_config,
)

# %% [markdown]
# 加入第二个llm驱动的角色：正方辩手

# %%
pro = RolePlayingAgent(
    name="正方",
    system_message=
    "你是一名辩手。"
    "先于反方发言。"
    "第一轮先陈述自己立场。"
    "除第一轮外每次对话反驳反方观点。",
    llm_config=llm_config,
)

# %% [markdown]
# 加入第三个llm驱动的角色：反方辩手

# %%
con = RolePlayingAgent(
    name="反方",
    system_message=
    "你是一名辩手。"
    "第一轮陈述自己立场后反拨正方观点。"
    "除第一轮外每次对话反驳正方观点。",
    llm_config=llm_config,
)

# %% [markdown]
# 将主持人、正方辩手、反方辩手拉进同一个会话

# %%
session = Session(participants=[host,pro,con])

# %% [markdown]
# 主持人先开始对话。（）必须人工输入辩论题目开启辩论。

# %%
session.append((host, "我是辩论赛主持人，今天辩论的题目是是否以成败论英雄，正方观点是以成败论英雄，反方观点是不以成败论英雄，请正方辩手先开始。"))

# %% [markdown]
# 进行两轮对话

# %%
session.chat(max_turns=2)
# Out:
# 主持人 (round 0)
#
# 我是辩论赛主持人，今天辩论的题目是是否以成败论英雄，正方观点是以成败论英雄，反方观点是不以成败论英雄，请正方辩手先开始。
#
# 正方 (round 0)
#
# 非常感谢辩论赛的主持人，让我们开始今天的辩论。正方的观点是：以成败论英雄。这个观点基于以下几个关键点来支撑我们的立场。
#
# 首先，历史上的英雄多数都是以他们的成就，即“成败”来定义的。伟大的领袖如凯撒、拿破仑、成吉思汗等，他们的名望和历史地位在很大程度上是基于他们所取得的军事胜利和政治改革成就。在某种程度上，他们的“英雄”称号与他们是如何改变时代的进程直接相关。
#
# 其次，我们不能忽视的是，在很多时候，英雄的行动是对社会、国家甚至是整个人类进步有着深远影响的。例如，图灵在数学和逻辑学上的贡献，以及他在战时对于密码破译的杰出成就，使他成为了信息时代的先驱，至今仍有深远的影响。在此类情况下，成败的标准往往与他们的远见和影响力直接联系，而非单纯的个人胜利或失败。
#
# 第三，从更现实的角度来看，以成败论英雄的基本出发点在于，英雄的特质和能力往往在面对重大挑战时才得以体现。无论是军事领袖在战场上的指挥，还是科研人员在绝境中找寻解决方案，这些成就往往可以展示英雄的本质和价值。
#
# 综上所述，正方认为，以成败论英雄不仅是合理合法的评价方式，也是理解和记住那些在历史上留下深远影响的人的重要途径。这种评价方式鼓励人们追求卓越，努力实现目标，无论是成功的胜利还是壮烈的失败，都是英雄精神的体现。我们期待反方辩手能够提供更多有力的反驳观点，让我们共同探讨这一主题的深刻含义。
#
# 反方 (round 0)
#
# 非常感谢正方辩手的精彩阐述，现在是我作为反方辩手对正方观点进行反驳的时候了。
#
# 反方的观点是：不以成败论英雄。我将从三个角度进行反驳：
#
# 首先，定义上的困惑。以成败论英雄，这个过程本身包含了预定的结论前提，即只有英雄一定会取得成功。然而在现实世界中，成功与否充满了不确定性，英雄之举也并不总是直接受到个体行为的直接反馈。很多时候，外界因素、历史偶然性甚至后世的评价都对成败结果产生影响。因此，将成就作为英雄的唯一的定义标准存在明显的主观性和不确定性。
#
# 其次，道德层面的关注。以成败作为评判英雄的标准，可能过分强调了个人与群体的收益和牺牲，忽视了道德行为、个性品质和社会责任的重要性。许多历史上的人物在关键时刻展现的正义感、勇敢、关爱他人等高尚品质，同样体现了英雄性，但在“成败”标准下，这些特质可能被忽视或低估。如海明威所说，“一个人不是被打败的，打不败的是人”，这恰恰强调了“失败者”的精神力量和道德价值。
#
# 最后，持久影响与历史脉络的考虑。如果简单地以结果定义英雄，那么成功者和强力的征服者可能被不恰当地简化为英雄。然而，历史学家和社会学家更关注的是个体对社会变革、文化的构建或道德伦理的贡献，而非他们的军事或经济成就。比如，马丁·路德·金不仅以其领导反种族隔离运动的成功而知名，更因其倡导的非暴力抵抗和平等正义理念，使他成为了不以成败论英雄的典范。
#
# 在综合考虑这些因素后，反方坚持认为，不以成败论英雄，更全面、更立体地评价英雄的价值，不仅能够更加准确地识别和肯定英雄的贡献，也能够为后世提供一个更加公正和全面的历史评价视角。
#
# ================================================================================
# 主持人 (round 1)
#
# 非常感谢反方辩手的精彩发言，全面而深入地探讨了“不以成败论英雄”这一观点。接下来，请正方辩手对反方辩手的观点进行回应或提出反驳意见。
#
# 正方 (round 1)
#
# 感谢主持人的组织工作，同时也感谢反方辩手的精彩辩驳。针对反方辩手的几点观点，我希望给出充分的论据和理由来回应：
#
# 首先，反方辩手论述的“定义上的困惑”确实是指出了“以成败论英雄”这一概念可能产生的单一化和偏见。然而，必须明确指出，任何评价标准都可能存有主观性和局限性。实际上，“成败”并不是唯一考量因素，它只是评估英雄的一个维度。其他维度可能包括对历史进程的深刻影响、对人类社会的贡献、个人品德、创新思想、伦理道德等等。以“成败”作为单一标准，并不意在完全取代其他维度的考虑，而是在现有的评价体系中一并平衡考量。
#
# 其次，反方辩手强调道德层面的重要性。虽然英雄的道德素质确实不应被忽视，但英雄的定义往往是在极端情境下，如危险、困境或危机中展现出超凡的勇气、领导力、智慧或其他正面特质的人。这种情况下，部分品质确实超越了纯粹的“道德”，而属于激励他人、塑造历史的品质。在现实世界中，我们尊重那些在关键时刻以牺牲个人利益为代价，追求正义、自由、和平等价值的人，这些人，无论他们是成功了还是失败了，都展现出超越普通人的英雄气概。
#
# 最后，对于“持久影响与历史脉络的考虑”，确实英雄的行为及其影响会跨越时间和空间的界限，对后人具有深远意义。历史人物的成功或失败往往是他们在特定情境下的结果，但这种评价不应削弱将历史人物视为普遍道德模范的重要性。历史人物通过他们的行为，提供了对当前社会和未来的道德、智慧、勇气的启示。因此，无论结果如何，只要这个人物能激发人们的精神力量、推动社会进步、弘扬正义，他们就可以称为英雄。
#
# 综上所述，我认为历史上的领袖和先驱之所以被后人所铭记，很大程度上是因为他们在超越单一人生成就的背景中，所展现的超乎常人的影响力和精神力量。我们要以更为全面、综合的视角来评价英雄，既要考虑他们的成败，也要思考他们的精神内涵和持久影响，以期更加公正、全面地定义英雄，从而更好地激励后人。
#
# 反方 (round 1)
#
# 非常感谢主持人给了我机会向反方辩手提问，同时也感谢反方再次精彩阐述他们的观点。你们的确提出了深刻的判断和犀利的辩论。为了回应你们的观点，我想提出一个关键问题。
#
# 在你们的辩论中，你们强调了英雄的道德品质、道德影响和长期影响的重要性。我赞同英雄的行为和影响应受到充分的考虑，因为它们不仅是主角在特定历史时期个人成就的衡量，还深刻影响了人类的普遍价值观念和社会发展。
#
# 然而，我们是否可以论定作为一个“英雄”的标准中，道德和社会影响是不是较为重要的因素，是否与成败有同等或更多的权重呢？是否可能有那么一位英雄，虽然在许多传统意义或是公认因素上的“成败”指标并非卓越，仅基于其独特的、对人类道德发展或是历史进程中不那么显著的关键贡献而被尊崇为英雄？
#
# 换言之，你们的论述中，是否承认了在衡量英雄时，除了成败之外，还应鼓励和考量那些可能不会在短期或宏观层面产生明显成效，甚至这种成效在一段时间内被忽略的贡献？这些可能包括对技术创新、哲学思考、文化传播等方面的长期、细微影响，或是在更隐蔽、私人的领域如教育、社会服务等，对社会进步做出的贡献。
#
# 这样的特点是否也值得我们计算在对英雄的定义之中？它们是否也在某种程度上构成了英雄概念的一部分，特别是在定义什么是“值得敬仰的英雄”时？这样是否更加全面、真实地反映了英雄在不同背景、生活条件和个人目标下的多样性的界定？
#
# ================================================================================

# %% [markdown]
# 由SummaryAgent总结对话

# %%
from zerollama.agents import SummaryAgent

# %%
summary_agent = SummaryAgent(
    system_message="总结下面对话",
    llm_config=llm_config)

print("总结:")
print(summary_agent.summary(session))
# Out:
# 总结:
# 这段对话是围绕辩论赛的主题“是否以成败论英雄”进行的，正方和反方辩手分别就各自的立场进行了详细的阐述和反驳。正方主要侧重于论辩历史上的英雄多数是基于其成就和影响作为评价标准，强调了英雄品质在极端情境下的体现。反方则从多角度出发，强调了“成败”评价标准的局限性，包括对道德层面的关注，对个体品质和社会影响的考量，以及对于可能在短期内不显眼的贡献的重视。双方的对话涉及丰富的人类价值观、历史解读和道德评判的多层面讨论，展现了对于英雄概念的深刻理解与多元视角的探索。
