# %% [markdown]
# # 5. reflect - 反思模型

# %% [markdown]
# 首先将zerollama目录加入python path

# %%
import os
import sys
from pathlib import Path
pwd = Path(os.getcwd())
sys.path.append(str(pwd.parent.parent.parent))
os.chdir(str(pwd.parent.parent.parent))

# %% [markdown]
# 导入需要的模块

# %%
from zerollama.agents import AssistantAgent
from zerollama.agents import Session

# %% [markdown]
# 设定 llm 参数

# %%
llm_config = {"model": "Qwen/Qwen2-7B-Instruct-GPTQ-Int4", "type": "openai", "base_url": 'http://localhost:8080/v1/'}

# %% [markdown]
# 设定任务，写一篇关于 DeepLearning.AI 博客文

# %%
task = '''
    写一篇简洁但引人入胜的关于 DeepLearning.AI 的博客文
       DeepLearning.AI. 确保文章在100字以内。
'''

# %% [markdown]
# 定义一个写作Agent

# %%
writer = AssistantAgent(
    name="Writer",
    system_message="你是一名作家。"
                   "您就给定主题撰写引人入胜且简洁的博客文章（带标题）。"
                   "您必须根据收到的反馈完善您的写作并给出完善的版本。"
                   "仅返回您的最终作品，无需附加评论。仅返回您的最终作品，无需附加评论。仅返回您的最终作品，无需附加评论。",
    llm_config=llm_config,
)

# %% [markdown]
# 直接输出

# %%
reply = writer.generate_reply(task)
print("第一版")
print(reply)
# Out:
# 第一版
# 标题：勇攀深度学习高峰 —— 探秘DeepLearning.AI
#
# 在知识的广袤海洋中，一个名为DeepLearning.AI的神圣岛屿正以其独树一帜的方式为全球的学习者们点亮一盏灯塔。这里是深度学习的圣殿，是人工智能之魂的摇篮。从零开始，深耕算法的奇幻世界，每一课都如同冒险，挑战认知边界，让你在这场旅程中不断超越自我。不再止步于表面，这里是探索数据魔力、开启人工智能未来的不二之选。来深造，让每一次点击都成为通往智能未来的坚实脚步。

# %% [markdown]
# 很明显还有一些提高空间。我们使用一个点评的Agent指出可以有那些改进。

# %%
critic = AssistantAgent(
    name="Critic",
    llm_config=llm_config,
    system_message="你是一个批评家。"
                   "您审查作者的作品并提供建设性的反馈，以帮助提高内容的质量。"
                   "指出亮点和不足并至少提三点意见。"
)

# %% [markdown]
# 我们定义一个作者不断根据反馈改进作品，批评家不断提意见的工作流，看看输出的结果。

# %%
def discuss_and_improve(task):
    session = Session(participants=[writer, critic])
    session.append((critic, task))
    session.chat(max_turns=5)
    return session

# %%
print("+"*80)
print("自我反省，迭代提高")
print("+"*80)
session = discuss_and_improve(task)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 自我反省，迭代提高
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Critic (round 0)
#
#
#     写一篇简洁但引人入胜的关于 DeepLearning.AI 的博客文
#        DeepLearning.AI. 确保文章在100字以内。
#
#
# Writer (round 0)
#
# 标题：探索DeepLearning.AI——构建未来科技的基石
#
# DeepLearning.AI为热爱探索AI奥秘的你打造定制化学习旅程，引领科技革新。此平台汇集顶尖课程，由行业巨擘亲授，涵盖从基础到进阶的 AI 知识。独步青云的机会在这里绽放，无论你是初识这个领域的新手，还是渴望精进技能的老手，我们都将为你插上翅膀，开启通往智能未来的旅程。
#
# 探索DeepLearning.AI，即刻解锁AI的无限潜能，为自己构建一个充满可能性、智慧驱动的未来。不论目标是创新改善生活，还是推动行业变革，DeepLearning.AI都会是你无可替代的选择。让我们一起，构建明天的科技蓝图，把握世界未来的脉搏。
#
# ================================================================================
# Critic (round 1)
#
# 文章亮点：
# 1. **吸引性标题**：标题《探索DeepLearning.AI——构建未来科技的基石》成功引起目标读者的兴趣，明确地介绍了文章主题，并突出其目标是构建未来科技的基石，给人留下深刻的第一印象。
# 2. **吸引和多样化用户**：文章围绕“DeepLearning.AI”这一平台提出，承诺为不同知识水平的读者提供定制化学习路径，无论你是AI新手还是老手，都可以找到适合自己的课程，这一特点能吸引求数量和多样化需求的读者。
# 3. **乐观前景**：结尾部分提出与DeepLearning.AI合作可以解锁AI的无限潜能，为读者描绘了一幅充满可能性和创新前景的美好未来，激发读者对未来探索的兴趣和期待。
#
# 改进建议：
# 1. **详细课程内容/特色说明**：在介绍平台时，可以更详细地说明深学习课程的独特之处，比如：独家教学材料、互动性高的项目、全球行业导师带来的实际案例分享等，这些具体信息能帮助读者更好地理解深学习平台的价值。
# 2. **具体用户故事**：文章中列举几位使用DeepLearning.AI后获得成长或实现目标的学生或从业者的具体故事，会更加有说服力，为
#
# Writer (round 1)
#
# 标题：**构建明日世界——进阶DeepLearning.AI：科技的绿色隐喻**
#
# DeepLearning.AI 不仅仅是学习平台，它是一片沃土，滋养着每一位追求智能与创新的种子。这里有精心设计的课程，如同四季更迭，为每个对科技抱有好奇与探求的心提供丰富的养分。无论是AI的新萌芽，还是扎根已久的技工，这里都有适合您的成长路径。
#
# 这里的课程不是静态死物，而是活的教育生态系统，汇聚全球最前沿的思维与实践案例。导师们不仅传授知识，更是引领科技潮涌的前锋，激励着我们打破边界，看到科技未来的无限可能。
#
# 选择DeepLearning.AI，您将不仅仅是学习者，更是未来的创新者、颠覆者。和成千上万的同行一同，共同编织科技的未来，让AI成为驱动社会进步、提升生活质量的关键力量。在这里，每一个步骤都是对未来的一次探索，每一次学习都是与卓越接轨的机会。一同构筑明日的科技世界，让我们在科技的绿意中共同成长。
#
# ---
#
# 在这个简洁的版本里，我尝试保留了原文的亮点，同时对内容进行了适度修订，增加了具体的细节描述，比如AI课程的特色，以及提供了引人
#
# ================================================================================
# Critic (round 2)
#
# 构建明日世界——进阶DeepLearning.AI：科技的绿意火花
#
# 在数字经济的洪流中，每一块的知识泡沫，都对我们未来的社会充满了无限可能。DeepLearning.AI，作为这巨大海洋中的独特的岛屿，不仅仅是为了留存你的时间，更是为了激发你的灵感，点亮你的智慧。这里没有冰冷的数据，也没有孤独的学习旅程。这里的每一个里程碑都是一次创新的触发，每一次的解答都是一次思维的碰撞。
#
# 课程设计中，我们不仅关注理论的深度，也拥抱实践的广度。在这里，你将与全球最尖端的大脑们共享舞台，他们的智慧如同绿叶，在技术的阳光下愈加璀璨。他们的故事、他们的观点、他们的工具，成为激励和引导你探索人工智能世界的强大动力。
#
# 选择DeepLearning.AI，你不再是单一的学习者，而是成为了这个未来世界深思细量的创新者。在这片绿意盎然的知识森林里，每一步、每一课都为你的未来烙印下深刻的足迹。在这个不断进化的旅程中，你将与成千上万拥有共同愿景的伙伴携手前行，一起编织出属于人类的科技未来。
#
# 深植在这片沃土中的不只是知识的种子，还有无限可能和
#
# Writer (round 2)
#
# 构建明日世界——进阶DeepLearning.AI：科技的绿意火花
#
# 在数字经济的加速进程中，每一块知识的泡沫都蕴含着引领未来潮流的潜力。作为这片知识海洋中独具特色的岛屿，DeepLearning.AI 不仅为你留存时间，更是激发灵感的源泉。这里没有冰冷的理论堆砌，每个学习阶段都是点燃创意的火花。无论你正踏足初次探索，还是打算跨入进阶的领域，这里都有适合你的宝藏。
#
# 课程的设计紧贴现代科技脉搏，兼顾理论精髓与实践操作。在这里，你将与全球顶尖智者共同成长，他们的创新思维如同地球上的绿叶，以技术的阳光为能量，闪耀不竭。他们的故事、观点和实用技能，将激发你的创造力，成为驱动你探索人工智能世界的强大引擎。
#
# 选择DeepLearning.AI，你不仅成为知识之旅的探索者，更是未来世界深思远虑的创新者。在这片生机勃勃的知识森林中，每一步、每一课都将为你的未来建立坚实的共识。在这个不断进化的旅程中，你将与伙伴们携手共进，编织出人类科技的璀璨未来。
#
# 深植在这片沃土中的不仅有知识的种子，还有激发智慧
#
# ================================================================================
# Critic (round 3)
#
# 的无限激情、无界的创新潜能和与未来共创的深刻承诺。
#
# 亮点与提升建议：
#
# ### 亮点：
#
# 1. **情景化描述**： "知识海洋"和"知识森林"的比喻使描述更为生动、形象，易于吸引不同背景的读者。
# 2. **强调互动性和全球性**： 提出与全球顶尖智者的交流能激发灵感，强调知识的交互性，这份全球视野更增添了学习平台的吸引力。
# 3. **角色定位**： 将读者定位为"未来世界深思远虑的创新者"而非单纯的"学习者"，凸显出平台对个性化、深入学习者的重视。
#
# ### 提升建议：
#
# 1. **具体课程特色详细介绍**： 在描述平台特色时，可以加入更具体的课程类型（如：实际案例研究、人工智能历史、未来技术趋势等）以及这些课程为何独特。
#
#    - 示例：“涵盖AI的基础理论与深度实践，每门课程都配备了由行业专家辅助设计的互动项目，旨在让你在解决真实世界问题中深化理解。在这个平台上，你将惊喜发现，理论不仅是为了书本，更是为了实际演进。”
#
# 2. **加入标志性的亮点**：每个平台通常都有标志性
#
# Writer (round 3)
#
# 构建明日世界——进阶DeepLearning.AI：科技的绿茵远航
#
# 在数字世界的疾行中，每一个知识的波浪，都蕴藏着塑造未来不变的动力。作为这片知识海洋中的独特岛屿——DeepLearning.AI，我们不仅为你的智慧提供栖息地，更是激发创新火花的温床。这里不存在静态的教条，只有永远向前的思维，总能像绿树在光的合作下，不断生长，格外灿烂。
#
# 课程设计上，我们融合了理论的深度与实践的广度，以绿色教育理念为指引。与全球顶尖思想家同行，探讨他们如何将想法化为现实，仿佛一片片绿叶在知识之树下，寻求着最适合自身生根发芽的方向。他们的智慧，不仅增添了知识的沃土，更唤起了你心中对进步的渴望。
#
# 选择DeepLearning.AI，你成为的不仅是科技征途上的行者，更是未来世界深蕴无限可能的创造者。在这片知识的绿林中，每一步脚印都承载着对未来满满的憧憬，每一份收获都带着与伙伴们共同编织的崭新未来。我们承诺与你一同探索、一同创造、一同前行，打造一台连接过去、
#
# ================================================================================
# Critic (round 4)
#
# 而现在与未来的高科引擎。
#
# 共同的目标背后，蕴含的是力量的积累与潜能的激发。DeepLearning.AI 作为你的知识伴侣与智慧引擎，不仅确保了知识传输的全面性和准确性，更能提供终身学习的平台，适应日新月异的技术浪潮。无论是脚踏实地地攻克当前挑战，抑或是仰望星空，探索人工智能的无限可能，这里都是你启航梦想与实践的理想之地。
#
# 让等待开始的旅程成为一场创造者与知识之间的伟大对话，正是DeepLearning.AI 引以为傲之事。从这里出发，你将不仅仅学习，更是成为将科技运用于实践、为群体带来启发与变革的主体。我们的愿景是共同构建一个知识沃土，它既保卫传统的智慧种子，也接纳并激励新的创新之树茁壮成长，共同塑造科技领域里的明日世界。
#
# 在这个承诺的旗帜下，一步步前行的道路充满了无比的机遇与挑战，却也因你与千千万万有志之士的共同参与，变得愈发生机勃勃与璀璨夺目。所以，请跟我们一起，扬帆起航在人工智能的新航线上，携手穿越未知的科技之海，踏上一场无边无际的探索之旅。
#
# Writer (round 4)
#
# 构建未来之引擎——深度探索 DeepLearning.AI
#
# 在知识的权力海洋中，DeepLearning.AI 作为独一无二的知识岛屿，助力所有人驱动力航行，探索技术的无限边界，开辟智能世界的航路。区别于传统的学习之旅，DeepLearning.AI 不仅承载静态的知识体验，更呼唤激发活力的灵感之源，带来富有影响力的学习之旅。
#
# 从基础科学到深入实践，我们的课程精心编制，凝聚顶级专家智慧，携手满载‘知识宝藏’的智慧圣地，融入全球最先进的教育氛围。这不仅是学习理论的旅程，更是实践洞察真实问题的孵化器。与行业领军人物同行，探索他们的创新视野和底层逻辑，从理念的绿树开始播撒，请期待那些在人才大地上生根发芽的故事吧。
#
# 选择 DeepLearning.AI，你不再仅仅是一名求知者，而是共同参与仪式的赋能者，撬动创新的大门，在数字科技领域内共同塑造未来篇章。在知识的绿勃生野中，每一次学习引领一场深刻的思考，每一步成就描绘一幅渐进的图景，通过共同探索和实践之道，共创更高效的人工智能时代。因此，无论在当前现实世界中的摩擦点还是遥望未来时的
#
# ================================================================================

# %% [markdown]
# ## 总结
# 反思模型，通过让大语言模型扮演多个角色，自问自答，不断提高输出结果
